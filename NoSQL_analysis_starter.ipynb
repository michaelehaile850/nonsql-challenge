# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={"scores.Hygiene":20}

# %%
# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(query)
count_documents
# Out:
# 41

# %%
# Display the first document in the results using pprint
first_doc =establishments.find_one(query)
pprint(first_doc)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65fd0ea87fecd2db6d4c63a4'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
# Convert the result to a Pandas DataFrame
results=establishments.find(query)
documents = list(results)
#convert to dataframe
df =pd.DataFrame(documents)
df.head(1)
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  65fd0ea87fecd2db6d4c63a4  110681                  0
#
#   LocalAuthorityBusinessID         BusinessName     BusinessType  \
# 0                     4029  The Chase Rest Home  Caring Premises
#
#    BusinessTypeID          AddressLine1 AddressLine2 AddressLine3  ...  \
# 0               5  5-6 Southfields Road   Eastbourne  East Sussex  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# ...

# %%
# Display the number of rows in the DataFrame
num_rows = len(df)
num_rows
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fd0ea87fecd2db6d4c63a4   110681                  0
# 1  65fd0ea87fecd2db6d4c671c   612039                  0
# 2  65fd0ea87fecd2db6d4c6a24   730933                  0
# 3  65fd0ea87fecd2db6d4c6c13   172735                  0
# 4  65fd0ea87fecd2db6d4c6c20   172953                  0
# 5  65fd0ea87fecd2db6d4c75c1   512854                  0
# 6  65fd0ea87fecd2db6d4c77f2  1537089                  0
# 7  65fd0ea87fecd2db6d4c8d0e   155648                  0
# 8  65fd0ea87fecd2db6d4c9154  1012883                  0
# 9  65fd0ea87fecd2db6d4c9961   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

query ={"LocalAuthorityName":"London","RatingValue":{"$gte":4}}

# %%
# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
count
# Out:
# 41

# %%
# Display the first document in the results using pprint
first_doc =establishments.find_one(query)
first_doc
# Out:
# {'_id': ObjectId('65fd0ea87fecd2db6d4c63a4'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.27694', 'latitude': '50.769705'},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
# ...

# %%
# Convert the result to a Pandas DataFrame
results =establishments.find(query)
documents = list(results)
df =pd.DataFrame(documents)
# Display the number of rows in the DataFrame
rows =len(df)
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fd0ea87fecd2db6d4c63a4   110681                  0
# 1  65fd0ea87fecd2db6d4c671c   612039                  0
# 2  65fd0ea87fecd2db6d4c6a24   730933                  0
# 3  65fd0ea87fecd2db6d4c6c13   172735                  0
# 4  65fd0ea87fecd2db6d4c6c20   172953                  0
# 5  65fd0ea87fecd2db6d4c75c1   512854                  0
# 6  65fd0ea87fecd2db6d4c77f2  1537089                  0
# 7  65fd0ea87fecd2db6d4c8d0e   155648                  0
# 8  65fd0ea87fecd2db6d4c9154  1012883                  0
# 9  65fd0ea87fecd2db6d4c9961   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score


penang_flavours = establishments.find_one({"BusinessName": "Penang Flavours"})

degree_search = 0.01
latitude = penang_flavours["geocode"]["latitude"] if penang_flavours else None
longitude = penang_flavours["geocode"]["longitude"] if penang_flavours else None

if latitude is not None and longitude is not None:
    query = {
        "RatingValue": 5,
        "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
        "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
    }

sort = [("scores.Hygiene", 1)]
limit = 5
results = establishments.find(query).sort(sort).limit(limit)

# %%
# Convert result to Pandas DataFrame
results = establishments.find(query).sort(sort).limit(limit)
df=pd.DataFrame(list(results))
df.head(1)
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  65fd0ea87fecd2db6d4c6c13  172735                  0
#
#   LocalAuthorityBusinessID   BusinessName            BusinessType  \
# 0             PI/000023858  Seaford Pizza  Takeaway/sandwich shop
#
#    BusinessTypeID   AddressLine1 AddressLine2 AddressLine3  ...  \
# 0            7844  4 High Street      Seaford  East Sussex  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.10202', 'latitude': '50.770885'}
#
#       Distance NewRatingPending  \
# 0  4620.421725            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create 

# Aggregation pipeline to count establishments with a hygiene score of 0 in each local authority
pipeline = [
    {
        '$match': {
            'scores.Hygiene': 0  # Match establishments with a hygiene score of 0
        }
    },
    {
        '$group': {
            '_id': '$LocalAuthorityName',  # Group by local authority name
            'count': {'$sum': 1}  # Count the number of establishments in each group
        }
    },
    {
        '$sort': {'count': -1}   Sort the results by count in descending order
    }
]

# Execute the aggregation pipeline
results = list(establishments.aggregate(pipeline))

# Print the results
for result in results:
    print(f"Local Authority: {result['_id']}, Establishments with Hygiene Score of 0: {result['count']}")
# Out:
# Local Authority: Thanet, Establishments with Hygiene Score of 0: 1130
# Local Authority: Greenwich, Establishments with Hygiene Score of 0: 882
# Local Authority: Maidstone, Establishments with Hygiene Score of 0: 713
# Local Authority: Newham, Establishments with Hygiene Score of 0: 711
# Local Authority: Swale, Establishments with Hygiene Score of 0: 686
# Local Authority: Chelmsford, Establishments with Hygiene Score of 0: 680
# Local Authority: Medway, Establishments with Hygiene Score of 0: 672
# Local Authority: Bexley, Establishments with Hygiene Score of 0: 607
# Local Authority: Southend-On-Sea, Establishments with Hygiene Score of 0: 586
# Local Authority: Tendring, Establishments with Hygiene Score of 0: 542
# Local Authority: Colchester, Establishments with Hygiene Score of 0: 498
# Local Authority: Tunbridge Wells, Establishments with Hygiene Score of 0: 491
# Local Authority: Folkestone and Hythe, Establishments with Hygiene Score of 0: 480
# ...

# %%
# Convert the result to a Pandas DataFrame

results = list(establishments.aggregate(pipeline))
df = pd.DataFrame(results)

# Rename columns for clarity
df.rename(columns={'_id': 'LocalAuthorityName', 'count': 'NumberOfEstablishments'}, inplace=True)

#Number of row
num =len(df)
num

# Display the DataFrame
df.head(10)
# Out:
#   LocalAuthorityName  NumberOfEstablishments
# 0             Thanet                    1130
# 1          Greenwich                     882
# 2          Maidstone                     713
# 3             Newham                     711
# 4              Swale                     686
# 5         Chelmsford                     680
# 6             Medway                     672
# 7             Bexley                     607
# 8    Southend-On-Sea                     586
# 9           Tendring                     542
